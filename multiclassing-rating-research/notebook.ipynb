# %%
import numpy as np
import matplotlib.pyplot as plt

# draw the graph of e^x
x = np.linspace(0, 5000, 100)
y = np.power(1.0005 , x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('e^x')
plt.title('')
plt.grid(True)
plt.show()
