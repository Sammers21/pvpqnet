# %%
import numpy as np
import matplotlib.pyplot as plt
import math as Math


# generate mumpy array with 5000 elements from 1 to 5000
x = np.linspace(1, 5000, 5000)
# generate mumpy array y using a custom function taking an element of x as input
def ladderScrore(x):
    if x>=1 and x<=50:
        # return 600 + (50 - x) * (400 / 50)
        return 600 + (50 - x) * (400 / 50)
    elif x>=51 and x<=100:
        return 400 + (100 - x) * (200 / 50)
    elif x>=101 and x<=5000:
        return 0 + Math.floor((5000 - x) * (400 / 4900))
    else:
        throw("x is out of range")
    
ladderScroreNp = np.frompyfunc(ladderScrore, 1, 1)
y = ladderScroreNp(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('')
plt.grid(True)
plt.show()
# Out:
# x:  1.0 y:  992.0
# x:  2.0 y:  984.0
# x:  3.0 y:  976.0
# x:  4.0 y:  968.0
# x:  5.0 y:  960.0
# x:  6.0 y:  952.0
# x:  7.0 y:  944.0
# x:  8.0 y:  936.0
# x:  9.0 y:  928.0
# x:  10.0 y:  920.0
# x:  11.0 y:  912.0
# x:  12.0 y:  904.0
# x:  13.0 y:  896.0
# x:  14.0 y:  888.0
# x:  15.0 y:  880.0
# x:  16.0 y:  872.0
# x:  17.0 y:  864.0
# x:  18.0 y:  856.0
# x:  19.0 y:  848.0
# x:  20.0 y:  840.0
# x:  21.0 y:  832.0
# x:  22.0 y:  824.0
# x:  23.0 y:  816.0
# x:  24.0 y:  808.0
# x:  25.0 y:  800.0
# x:  26.0 y:  792.0
# x:  27.0 y:  784.0
# x:  28.0 y:  776.0
# x:  29.0 y:  768.0
# x:  30.0 y:  760.0
# x:  31.0 y:  752.0
# x:  32.0 y:  744.0
# x:  33.0 y:  736.0
# x:  34.0 y:  728.0
# x:  35.0 y:  720.0
# x:  36.0 y:  712.0
# x:  37.0 y:  704.0
# x:  38.0 y:  696.0
# x:  39.0 y:  688.0
# x:  40.0 y:  680.0
# x:  41.0 y:  672.0
# x:  42.0 y:  664.0
# x:  43.0 y:  656.0
# x:  44.0 y:  648.0
# x:  45.0 y:  640.0
# x:  46.0 y:  632.0
# x:  47.0 y:  624.0
# x:  48.0 y:  616.0
# ...
